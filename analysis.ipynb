# %% [markdown]
# # Dimensionaltiy Reduction Comparison and Stuff
#
# something goes here

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Mmmmm colors.

# %%
sns.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# ## The Data

# %%
df = pd.read_pickle('./results.pkl')
df.head()
# Out:
#         model  chunk_size  overlap  embedding_dim   accuracy query_size  \
# 0  contriever         100      0.0              1   2.800000   (25, 50)
# 1  contriever         100      0.0              3  10.914286   (25, 50)
# 2  contriever         100      0.0              5  23.085714   (25, 50)
# 3  contriever         100      0.0              7  34.457143   (25, 50)
# 4  contriever         100      0.0              9  41.657143   (25, 50)
#
#       space
# 0  0.013443
# 1  0.040329
# 2  0.067215
# 3  0.094101
# 4  0.120987

# %%
# sns.scatterplot(data=df, x='embedding_dim', y='accuracy', hue='query_size')
sns.lineplot(data=df, x='embedding_dim', y='accuracy', hue='query_size')
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.lineplot(data=df, x='embedding_dim', y='accuracy', hue='model')
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.kdeplot(data=df,
            x='embedding_dim',
            y='accuracy',
            hue='chunk_size',
            fill=True,
            common_norm=False,
            alpha=.5)
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.kdeplot(data=df,
            x='embedding_dim',
            y='accuracy',
            hue='overlap',
            fill=True,
            common_norm=False,
            alpha=.5)
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
threshold = 97
df[(df['accuracy'] >= threshold) & (df['query_size'] == (25,50)) ].sort_values(by=['space']).head()
# Out:
#           model  chunk_size  overlap  embedding_dim   accuracy query_size  \
# 184  contriever         100     0.15             96  97.085714   (25, 50)
# 35   contriever         100     0.00            115  97.142857   (25, 50)
# 85   contriever         100     0.05            115  97.314286   (25, 50)
# 686  contriever         150     0.30            134  97.028571   (25, 50)
# 587  contriever         150     0.20            153  97.085714   (25, 50)
#
#         space
# 184  1.517282
# 35   1.545941
# 85   1.625183
# 686  1.701952
# 587  1.702976

# %%
threshold = 85
df[(df['accuracy'] >= threshold) & (df['query_size'] == (50,100)) ].sort_values(by=['space']).head()
# Out:
#        model  chunk_size  overlap  embedding_dim   accuracy query_size  \
# 24215  mpnet         400     0.05             30  85.314286  (50, 100)
# 24166  mpnet         400     0.00             32  85.485714  (50, 100)
# 23913  mpnet         350     0.10             26  85.142857  (50, 100)
# 24265  mpnet         400     0.10             30  85.371429  (50, 100)
# 24216  mpnet         400     0.05             32  85.314286  (50, 100)
#
#           space
# 24215  0.103639
# 24166  0.105284
# 23913  0.108220
# 24265  0.109412
# 24216  0.110548
