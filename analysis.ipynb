# %% [markdown]
# # Dimensionaltiy Reduction Comparison and Stuff
#
# Still have some data to add.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Mmmmm colors.

# %%
sns.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# ## The Data

# %%
df = pd.read_pickle('./results.pkl')
df.tail()
# Out:
#            model  chunk_size  overlap  embedding_dim   accuracy query_size
# 5395  contriever         500      0.3            614  68.228571   (25, 50)
# 5396  contriever         500      0.3            652  68.285714   (25, 50)
# 5397  contriever         500      0.3            691  68.114286   (25, 50)
# 5398  contriever         500      0.3            729  68.171429   (25, 50)
# 5399  contriever         500      0.3            768  81.142857   (25, 50)

# %%
sns.scatterplot(data=df, x='embedding_dim', y='accuracy', hue='query_size')
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.scatterplot(data=df, x='embedding_dim', y='accuracy', hue='chunk_size')
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
df[df['chunk_size']==400][df['overlap']==0.1]
# Out:
# C:\Users\hongj\AppData\Local\Temp\ipykernel_4820\858875410.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['chunk_size']==400][df['overlap']==0.1]
#            model  chunk_size  overlap  embedding_dim   accuracy query_size
# 1850  contriever         400      0.1              3   6.800000  (50, 100)
# 1851  contriever         400      0.1              7  13.542857  (50, 100)
# 1852  contriever         400      0.1             11  17.714286  (50, 100)
# 1853  contriever         400      0.1             15  25.257143  (50, 100)
# 1854  contriever         400      0.1             19  34.171429  (50, 100)
# 1855  contriever         400      0.1             23  38.228571  (50, 100)
# 1856  contriever         400      0.1             26  40.742857  (50, 100)
# 1857  contriever         400      0.1             30  47.028571  (50, 100)
# 1858  contriever         400      0.1             34  51.485714  (50, 100)
# 1859  contriever         400      0.1             38  54.400000  (50, 100)
# 1860  contriever         400      0.1             42  56.114286  (50, 100)
# 1861  contriever         400      0.1             46  60.228571  (50, 100)
# 1862  contriever         400      0.1             49  61.657143  (50, 100)
# 1863  contriever         400      0.1             53  65.257143  (50, 100)
# 1864  contriever         400      0.1             57  67.428571  (50, 100)
# 1865  contriever         400      0.1             61  70.742857  (50, 100)
# 1866  contriever         400      0.1             65  73.428571  (50, 100)
# 1867  contriever         400      0.1             69  74.742857  (50, 100)
# 1868  contriever         400      0.1             72  76.228571  (50, 100)
# 1869  contriever         400      0.1             76  76.800000  (50, 100)
# 1870  contriever         400      0.1             80  79.600000  (50, 100)
# 1871  contriever         400      0.1             84  79.600000  (50, 100)
# 1872  contriever         400      0.1             88  80.628571  (50, 100)
# 1873  contriever         400      0.1             92  81.942857  (50, 100)
# 1874  contriever         400      0.1             96  82.628571  (50, 100)
# 1875  contriever         400      0.1             99  83.485714  (50, 100)
# 1876  contriever         400      0.1            103  84.342857  (50, 100)
# 1877  contriever         400      0.1            107  84.857143  (50, 100)
# 1878  contriever         400      0.1            111  86.685714  (50, 100)
# 1879  contriever         400      0.1            115  86.514286  (50, 100)
# 1880  contriever         400      0.1            119  87.314286  (50, 100)
# 1881  contriever         400      0.1            122  86.971429  (50, 100)
# 1882  contriever         400      0.1            126  87.771429  (50, 100)
# 1883  contriever         400      0.1            153  90.057143  (50, 100)
# 1884  contriever         400      0.1            192  92.400000  (50, 100)
# 1885  contriever         400      0.1            230  93.485714  (50, 100)
# 1886  contriever         400      0.1            268  94.285714  (50, 100)
# 1887  contriever         400      0.1            307  94.742857  (50, 100)
# 1888  contriever         400      0.1            345  95.028571  (50, 100)
# 1889  contriever         400      0.1            384  95.314286  (50, 100)
# 1890  contriever         400      0.1            422  95.600000  (50, 100)
# 1891  contriever         400      0.1            460  95.542857  (50, 100)
# 1892  contriever         400      0.1            499  95.942857  (50, 100)
# 1893  contriever         400      0.1            537  95.885714  (50, 100)
# 1894  contriever         400      0.1            576  95.828571  (50, 100)
# 1895  contriever         400      0.1            614  96.171429  (50, 100)
# 1896  contriever         400      0.1            652  96.171429  (50, 100)
# 1897  contriever         400      0.1            691  96.114286  (50, 100)
# 1898  contriever         400      0.1            729  96.285714  (50, 100)
# 1899  contriever         400      0.1            768  98.514286  (50, 100)
