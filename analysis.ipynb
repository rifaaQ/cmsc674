# %% [markdown]
# # Dimensionaltiy Reduction Comparison and Stuff
#
# something goes here

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Mmmmm colors.

# %%
sns.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# ## The Data

# %%
df = pd.read_pickle('./results.pkl')
df.head()
# Out:
#         model  chunk_size  overlap  embedding_dim   accuracy query_size  \
# 0  contriever         100     0.05              1   2.800000   (25, 50)
# 1  contriever         100     0.05              3  10.342857   (25, 50)
# 2  contriever         100     0.05              5  22.800000   (25, 50)
# 3  contriever         100     0.05              7  32.628571   (25, 50)
# 4  contriever         100     0.05              9  41.942857   (25, 50)
#
#       space
# 0  0.002604
# 1  0.007812
# 2  0.013021
# 3  0.018229
# 4  0.023438

# %%
# sns.scatterplot(data=df, x='embedding_dim', y='accuracy', hue='query_size')
sns.lineplot(data=df, x='embedding_dim', y='accuracy', hue='query_size')
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.lineplot(data=df, x='embedding_dim', y='accuracy', hue='model')
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.kdeplot(data=df,
            x='embedding_dim',
            y='accuracy',
            hue='chunk_size',
            fill=True,
            common_norm=False,
            alpha=.5)
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
sns.kdeplot(data=df,
            x='embedding_dim',
            y='accuracy',
            hue='overlap',
            fill=True,
            common_norm=False,
            alpha=.5)
# Out:
# <AxesSubplot:xlabel='embedding_dim', ylabel='accuracy'>

# %%
threshold = 97
df[(df['accuracy'] >= threshold) & (df['query_size'] == (25,50)) ].sort_values(by=['space']).head()
# Out:
#           model  chunk_size  overlap  embedding_dim   accuracy query_size  \
# 234  contriever         100     0.25             96  97.371429   (25, 50)
# 35   contriever         100     0.05            115  97.200000   (25, 50)
# 285  contriever         100     0.30            115  97.485714   (25, 50)
# 235  contriever         100     0.25            115  98.057143   (25, 50)
# 135  contriever         100     0.15            115  97.771429   (25, 50)
#
#         space
# 234  0.250000
# 35   0.299479
# 285  0.299479
# 235  0.299479
# 135  0.299479

# %%
threshold = 97
df[(df['accuracy'] >= threshold) & (df['query_size'] == (50,100)) ].sort_values(by=['space']).head()
# Out:
#            model  chunk_size  overlap  embedding_dim   accuracy query_size  \
# 2964  contriever         100      0.3             28  97.028571  (50, 100)
# 8364      minilm         100      0.3             28  97.314286  (50, 100)
# 8365      minilm         100      0.3             30  97.542857  (50, 100)
# 2965  contriever         100      0.3             30  97.714286  (50, 100)
# 2865  contriever         100      0.2             30  97.028571  (50, 100)
#
#          space
# 2964  0.072917
# 8364  0.072917
# 8365  0.078125
# 2965  0.078125
# 2865  0.078125
